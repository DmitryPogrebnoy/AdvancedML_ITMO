# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn import datasets
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("ex1_data.csv", header=None)
data
# Out:
#             0          1          2          3          4          5  \
# 0  -24.504942  23.577457 -13.013497  11.597908  18.342250  -2.258323
# 1   -8.712978 -16.467314 -15.739045 -15.125727   2.382873  -0.332771
# 2   -4.947666  -5.762710 -15.296801   3.076486 -27.540477  24.642389
# 3   -4.711577  -7.501066 -14.611638   2.005721 -26.131699  20.563434
# 4   -2.027430  -6.786353 -15.435602  -0.508896 -24.222880  22.565825
# 5  -20.023479  27.198949 -14.766452  10.014044  17.375954  -2.990330
# 6  -25.763795  26.414939 -15.906973  10.706174  13.324990  -0.339442
# 7  -22.194366  23.872249 -17.255391  12.244451  17.147069  -3.014914
# 8   -7.371201  -3.289029 -15.259983  11.489385   4.321197  21.221373
# 9   -4.533204  -3.405554 -17.659972   2.446106 -21.751865  23.299453
# 10  -4.516392  -3.628664 -14.709475  12.056482   5.414088  20.200729
# 11 -10.297033 -17.105752 -16.896448 -16.476800   4.337911   0.943718
# 12 -13.849198 -15.958813 -13.253914 -17.394658  22.428370   6.209193
# ...

# %%
pca = PCA(n_components=1, svd_solver='full') #PCA class object creation. The number of PCs and optimization method are the parameters
data_transformed = pca.fit(data).transform(data) #X_transformed -- ndarray of the objects, where each object is described by 2 PCs

# %%
data_transformed[0]
# Out:
# array([36.23343741])

# %%
pca = PCA(n_components=2, svd_solver='full') #PCA class object creation. The number of PCs and optimization method are the parameters
data_transformed = pca.fit(data).transform(data) #X_transformed -- ndarray of the objects, where each object is described by 2 PCs

# %%
data_transformed
# Out:
# array([[ 36.23343741,   5.10043679],
#        [ -5.59941446, -17.20232801],
#        [-27.09188256,  36.48864231],
#        [-24.89267096,  32.86344678],
#        [-26.07908242,  32.73498344],
#        [ 38.29260928,   6.7777955 ],
#        [ 39.19826844,   8.65274846],
#        [ 39.04054137,   5.53680497],
#        [ 23.86588669,   0.49511265],
#        [-23.48346266,  31.24453545],
#        [ 24.81892463,  -1.61617884],
#        [ -5.9014377 , -19.09552215],
#        [-26.07078459, -19.58380917],
#        [ 38.97513249,   8.45882596],
#        [-26.56285995, -20.84606386],
#        [ 38.90467114,   6.51770563],
#        [-28.42370998, -18.35636067],
#        [-30.81940618, -19.40228917],
#        [ 41.33674302,   5.96371776],
#        [ -8.50761322, -18.64121625],
#        [ 38.28478768,   7.01900549],
#        [ -8.76183084, -19.2301936 ],
#        [ -7.90477927, -19.74681967],
#        [-29.9494716 , -18.11103543],
#        [ -8.98194057, -19.20821382],
# ...

# %%
pca = PCA(n_components=10, svd_solver='full') #PCA class object creation. The number of PCs and optimization method are the parameters
data_transformed = pca.fit(data).transform(data) #X_transformed -- ndarray of the objects, where each object is described by 2 PCs

# %%
explained_variance = np.round(np.cumsum(pca.explained_variance_ratio_), 3)
explained_variance
# Out:
# array([0.46 , 0.695, 0.923, 0.992, 0.994, 0.996, 0.997, 0.998, 0.999,
#        1.   ])

# %%
plt.scatter(data_transformed[:61, 0], data_transformed[:60, 1],edgecolor='none', s=40,cmap='winter')
